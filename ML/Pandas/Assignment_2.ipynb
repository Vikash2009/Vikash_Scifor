# %%
# create your series object AS S1 WHICH HOLDS THE VALUES IN THE LIST FORMAT
# CREATE A SERIES OBJECT WHICH STORE THE INITIAL BUDGET VALUE(30000) FOR EACH QUARTER OF YEAR
# CREATE A SERIES OBJECT USING THE ND ARRAY WHICH HAS 10 ELEMENTS IN THE RANGER OF 0-70
# WRITE A SERIES OBJECT USING DICT WHICH STORES THE TOTAL HINDI MARKS OF STUDENTS OF EACH 4 SECTIONS
# THE TOTAL NO OF QUES ASKED IN AN EXAM WAS 200 WHICH HELD EVERY 2 YEARS CREATE A SERIES OBJECT WHICH STORES 200 QUES IN THE TIME PEROD FROM 2002- 2023

# %%
# importing libraries
import pandas as pd
import numpy as np

# %%
l1 = ['s','c','i','f','o','r']
s1=pd.Series(l1)
s1
# Out:
# 0    s
# 1    c
# 2    i
# 3    f
# 4    o
# 5    r
# dtype: object

# %%
s2=pd.Series(30000,index =['q1','q2','q3','q4'])
s2
# Out:
# q1    30000
# q2    30000
# q3    30000
# q4    30000
# dtype: int64

# %%
nd_array=np.linspace(0,70,5)
s3=pd.Series(nd_array)
s3
# Out:
# 0     0.0
# 1    17.5
# 2    35.0
# 3    52.5
# 4    70.0
# dtype: float64

# %%
marks={'sec_A':1000,
       'sec_b':2000,
       'sec_c':2500,
       'sec_d':3000}
s4=pd.Series(marks)
s4
# Out:
# sec_A    1000
# sec_b    2000
# sec_c    2500
# sec_d    3000
# dtype: int64

# %%
years=range(2002,2024,2)
s5=pd.Series(200,years)
s5
# Out:
# 2002    200
# 2004    200
# 2006    200
# 2008    200
# 2010    200
# 2012    200
# 2014    200
# 2016    200
# 2018    200
# 2020    200
# 2022    200
# dtype: int64
